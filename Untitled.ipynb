# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import pandas as pd 
import numpy as np

import seaborn as sns

# %%
df_csv = pd.read_csv('fifa_players.csv')

# %%
df_csv.isna().sum()
# Out:
# name                                 0
# full_name                            0
# birth_date                           0
# age                                  0
# height_cm                            0
# weight_kgs                           0
# positions                            0
# nationality                          0
# overall_rating                       0
# potential                            0
# value_euro                         255
# wage_euro                          246
# preferred_foot                       0
# international_reputation(1-5)        0
# weak_foot(1-5)                       0
# skill_moves(1-5)                     0
# body_type                            0
# release_clause_euro               1837
# national_team                    17097
# crossing                             0
# finishing                            0
# heading_accuracy                     0
# short_passing                        0
# volleys                              0
# ...

# %%
correlation = df_csv["age"].corr(df_csv["overall_rating"])

# %%
correlation_matrix
# Out:
# 0.461529221321258

# %%
sns.heatmap(df_csv["age"].corr(df_csv["overall_rating"]) , cmap='coolwarm',  annot=True, fmt=".2f")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 sns.heatmap(df_csv["age"].corr(df_csv["overall_rating"]) , cmap='coolwarm',  annot=True, fmt=".2f")
#       2 plt.show()
#
# File ~\anaconda3\Lib\site-packages\seaborn\matrix.py:446, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     365 """Plot rectangular data as a color-encoded matrix.
#     366
#     367 This is an Axes-level function and will draw the heatmap into the
#    (...)
#     443
#     444 """
#     445 # Initialize the plotter object
# --> 446 plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     447                       annot_kws, cbar, cbar_kws, xticklabels,
#     448                       yticklabels, mask)
# ...

# %%
df_csv.loc[[0] , ["nationality"]]
# Out:
#   nationality
# 0   Argentina

# %%
df_csv.iloc[[0] , [0]]
# Out:
#        name
# 0  L. Messi

# %%
df = df_csv[df_csv["overall_rating"] > 90]
df
# Out:
#                     name                            full_name birth_date  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini  6/24/1987   31
# 17938          L. Suárez             Luis Alberto Suárez Díaz  1/24/1987   32
# 17939          L. Modrić                          Luka Modrić   9/9/1985   33
# 17940          E. Hazard                          Eden Hazard   1/7/1991   28
# 17941       K. De Bruyne                      Kevin De Bruyne  6/28/1991   27
# 17942             De Gea                David De Gea Quintana  11/7/1990   28
# 17943          Neymar Jr        Neymar da Silva Santos Junior   2/5/1992   27
# 17944  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   2/5/1985   34
#
#        height_cm  weight_kgs positions nationality  overall_rating  potential  \
# 0         170.18        72.1  CF,RW,ST   Argentina              94         94
# 17938     182.88        86.2        ST     Uruguay              91         91
# ...

# %%
df_csv.describe()
# Out:
#                 age     height_cm    weight_kgs  overall_rating     potential  \
# count  17954.000000  17954.000000  17954.000000    17954.000000  17954.000000
# mean      25.565445    174.946921     75.301047       66.240169     71.430935
# std        4.705708     14.029449      7.083684        6.963730      6.131339
# min       17.000000    152.400000     49.900000       47.000000     48.000000
# 25%       22.000000    154.940000     69.900000       62.000000     67.000000
# 50%       25.000000    175.260000     74.800000       66.000000     71.000000
# 75%       29.000000    185.420000     79.800000       71.000000     75.000000
# max       46.000000    205.740000    110.200000       94.000000     95.000000
#
#          value_euro      wage_euro  international_reputation(1-5)  \
# count  1.769900e+04   17708.000000                   17954.000000
# mean   2.479280e+06    9902.134628                       1.111674
# std    5.687014e+06   21995.593750                       0.392168
# ...

# %%
plt.plot(df["name"] , df["overall_rating"] , marker = "o" , ls = "--")
plt.show()

# %%
plt.scatter(df["name"] , df["overall_rating"])
plt.show()

# %%
plt.bar(df["name"] , df["overall_rating"])
plt.xlabel("name")
plt.ylabel("overall_rating")
plt.show()

# %%
plt.plot(df["name"] , df["overall_rating"])
plt.show()

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
df_csv.isnull().sum()
# Out:
# name                                 0
# full_name                            0
# birth_date                           0
# age                                  0
# height_cm                            0
# weight_kgs                           0
# positions                            0
# nationality                          0
# overall_rating                       0
# potential                            0
# value_euro                         255
# wage_euro                          246
# preferred_foot                       0
# international_reputation(1-5)        0
# weak_foot(1-5)                       0
# skill_moves(1-5)                     0
# body_type                            0
# release_clause_euro               1837
# national_team                    17097
# crossing                             0
# finishing                            0
# heading_accuracy                     0
# short_passing                        0
# volleys                              0
# ...
